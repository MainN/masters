# %%
import epi_process 
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

# %%
ep = epi_process.EpiProcessViz(size=1000, percent=1)

# %%
ep.show_graph()
print(ep.result)
# Out:
# [10]

# %%
ep.iterartion()
ep.show_graph()
print(ep.result)
# Out:
# [10, 15]

# %%
ep.iterartion()
ep.show_graph()
print(ep.result)
# Out:
# [10, 15, 96]

# %%
ep.iterartion()
ep.show_graph()
print(ep.result)
# Out:
# [10, 15, 96, 175]

# %%
ep.iterartion()
ep.iterartion()
ep.iterartion()
ep.iterartion()
ep.iterartion()
ep.show_graph()
print(ep.result)
# Out:
# [10, 15, 96, 175, 178, 100, 74, 29, 9]
